# %%
# %%capture
# %load_ext autoreload
# %autoreload 2

# %%
import tqdm

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from scikit-surprise) (2.1.1)
# Requirement already satisfied: scipy>=1.6.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from scikit-surprise) (1.14.1)

# %%
# !pip install ipywidgets --upgrade
# Out:
# Requirement already satisfied: ipywidgets in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %% [markdown]
# ## Load and Preprocess MovieLens Dataset

# %%
import requests
import pandas as pd
from io import BytesIO
from zipfile import ZipFile

# URL for the MovieLens 1M dataset
url = 'https://files.grouplens.org/datasets/movielens/ml-1m.zip'

# Download the dataset
response = requests.get(url)
if response.status_code != 200:
    raise Exception("Failed to download the dataset")

# Extract the zip file
with ZipFile(BytesIO(response.content)) as zfile:
    # List the files in the zip archive
    zfile.printdir()
    
    with zfile.open('ml-1m/movies.dat') as movies_file:
        movie_data = pd.read_csv(movies_file,
                                 sep='::', 
                                 header=None, 
                                 names=['movieId', 'title', 'genres'],
                                 engine='python',
                                 encoding='ISO-8859-1')
        
# Display the head of the datasets
print("\nMovies:")
print(movie_data.head())
# Out:
# File Name                                             Modified             Size
# ml-1m/                                         2016-01-29 14:39:34            0
# ml-1m/movies.dat                               2003-03-26 15:18:14       171308
# ml-1m/ratings.dat                              2003-02-28 15:53:08     24594131
# ml-1m/README                                   2016-01-29 14:39:34         5577
# ml-1m/users.dat                                2003-02-28 15:53:08       134368
#
# Movies:
#    movieId                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
import numpy as np
from surprise import accuracy, Dataset, SVD
from surprise.model_selection import train_test_split

# Load the movielens-100k dataset (download it if needed),
data = Dataset.load_builtin("ml-1m")

# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=0.25)

# We'll use the famous SVD algorithm.
NUM_FEATURES = 5
algo = SVD(n_factors=NUM_FEATURES, biased=False, random_state=42)

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)

# Estimate rating noise (sigma) from the data
sigma = np.std(np.array([prediction.est for prediction in predictions]) - np.array([prediction.r_ui for prediction in predictions]))
print("sigma =", sigma)
# Out:
# RMSE: 0.8866
# sigma = 0.8859548580570763

# %%
import pandas as pd
from collections import defaultdict

# Function to compute average ratings for each movie
def compute_movie_avg_ratings(trainset):
    movie_ratings = defaultdict(list)
    for uid, iid, rating in trainset.all_ratings():
        # print(uid, iid, rating)
        movie_ratings[trainset.to_raw_iid(iid)].append(rating)
    avg_ratings = {int(iid): np.mean(ratings) for iid, ratings in movie_ratings.items() if len(ratings) > 100}
    return avg_ratings

# Compute average ratings and select the top K movies
avg_ratings = compute_movie_avg_ratings(trainset)
NUM_ACTIONS = 2
offset = 0
top_k_movies = sorted(avg_ratings, key=avg_ratings.get, reverse=True)[offset:offset+NUM_ACTIONS]
# top_k_movies = random.sample([k for k in range(len(avg_ratings))], NUM_ACTIONS)

# Create a dictionary to map movieId to title
movie_id_to_title = dict(zip(movie_data['movieId'], movie_data['title']))

# Get the titles of the top K movies
top_k_movie_titles = [movie_id_to_title[movie_id] for movie_id in top_k_movies]

# Print the titles of the top K movies
print(f"Top K = {NUM_ACTIONS} movies:")
for title in top_k_movie_titles:
    print(title)
# Out:
# Top K = 2 movies:
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)
# Shawshank Redemption, The (1994)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# Obtain user latent factors from the trained SVD model
user_latent_factors = algo.pu

# Obtain movie latent factors from the trained SVD model
movie_latent_factors = algo.qi

# Apply k-means clustering
NUM_SOURCES = 5
kmeans = KMeans(n_clusters=NUM_SOURCES, random_state=42)
user_clusters = kmeans.fit_predict(user_latent_factors)

# Reduce dimensions using t-SNE
tsne = TSNE(n_components=2, random_state=42)
user_latent_2d = tsne.fit_transform(user_latent_factors)

# Create a DataFrame for visualization
tsne_df = pd.DataFrame({
    'tsne_1': user_latent_2d[:, 0],
    'tsne_2': user_latent_2d[:, 1],
    'cluster': user_clusters
})

# Plot the t-SNE embedding
plt.figure(figsize=(10, 8))
sns.scatterplot(
    x='tsne_1', y='tsne_2',
    hue='cluster',
    palette=sns.color_palette('hsv', num_clusters),
    data=tsne_df,
    legend='full',
    alpha=0.8
)
plt.title('t-SNE Visualization of User Latent Factors Colored by K-Means Clusters')
plt.show()
# Out:
# /Users/gael/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ## Generate Logged Dataset

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)

# %%
NUM_SOURCES = 3
NUM_ACTIONS = 2
NUM_SAMPLES = [1_000] * NUM_SOURCES
NUM_FEATURES = 4


def create_multi_task_bandit_dataset_with_action_dependent_context(
        num_interactions=500,
        num_tasks=NUM_SOURCES, 
        num_actions=NUM_ACTIONS, 
        num_context_dims=NUM_FEATURES,  
        sigma_q=1.0,        # Controls hyperparameter uncertainty
        sigma_0=5.0,        # Task covariance
        reward_noise=1.0    # Reward noise
):
    
    # Hyperprior mean and covariance (for sampling mu*)
    mu_prior_mean = np.zeros(num_context_dims)
    mu_prior_cov = np.eye(num_context_dims) * sigma_q**2

    # Sample hyperparameter mu*
    mu_star = np.random.multivariate_normal(mu_prior_mean, mu_prior_cov)

    # Task-specific parameters theta_s* (sampled for each task)
    task_params = []
    task_cov = np.eye(num_context_dims) * sigma_0**2
    for _ in range(num_tasks):
        theta_s_star = np.random.multivariate_normal(mu_star, task_cov)
        task_params.append(theta_s_star)
    
    task_params = np.array(task_params)  # Shape: (num_tasks, num_context_dims)

    # Generate the dataset
    data = {}

    for task_id in range(num_tasks):
        task_data = {
            'contexts': [],
            'actions': [],
            'rewards': [],
            'true_rewards': []
        }

        if task_id == NUM_SOURCES - 1:
            theta_s_star = task_params[task_id]
        else:
            theta_s_star = task_params[0]

        for t in range(num_interactions):
            # Generate a context-action vector for each action (action-dependent context)
            context_action_vectors = np.random.uniform(-1, 1, (num_actions, num_context_dims))

            # Compute true rewards for all actions: φ(x, a) ^ T θ_s*
            true_rewards = 2 * (1 + np.dot(context_action_vectors, theta_s_star))

            # Sample a random action
            if t < 2 * NUM_ACTIONS:
                action = t % NUM_ACTIONS
            else:
                action = np.random.choice(num_actions)

            # Observe the reward for the selected action with noise
            observed_reward = np.random.normal(true_rewards[action], reward_noise)

            # Store the context (the selected action's context vector), reward, action, and true rewards vector
            task_data['contexts'].append(context_action_vectors[action])
            task_data['actions'].append(str(action))
            task_data['rewards'].append(observed_reward)
            task_data['true_rewards'].append(true_rewards)

        print(np.mean(task_data["true_rewards"], axis=0))
        
        # Convert lists to numpy arrays for easier manipulation later
        data[task_id] = [np.array(task_data['contexts']), np.array(task_data['rewards']), task_data['actions'], np.array(task_data['true_rewards'])]

    # return data, task_params, mu_star
    return data

# %%
# Create observational dataset
# NUM_SOURCES = num_tasks
N = 500
train_data = create_multi_task_bandit_dataset_with_action_dependent_context(num_interactions=N)
eval_data = create_multi_task_bandit_dataset_with_action_dependent_context(num_interactions=2*N)
test_data = create_multi_task_bandit_dataset_with_action_dependent_context(num_interactions=100)
# Out:
# [1.63270752 1.83021531]
# [1.97250494 1.74895671]
# [1.98540221 2.04939406]
# [2.06297976 1.93573163]
# [1.90329286 1.89481724]
# [1.98847997 1.95475243]
# [ 1.87098328 -0.49651599]
# [1.03480288 1.37694125]
# [0.39865841 1.14527323]

# %% [markdown]
# # Run Experiments

# %%
from src.egpolicytree import EGPolicyTree
from src import utils

# %%
num_weights = NUM_SOURCES
num_iterations = N
learning_rate = np.sqrt(np.log(num_weights) / num_iterations) / 10
print(learning_rate)

cover = []
for i in range(num_weights):
    distribution = np.zeros(num_weights)
    distribution[i] = 1
    cover.append(distribution)
print(cover)
# Out:
# 0.005265537695468319
# [array([1., 0., 0., 0.]), array([0., 1., 0., 0.]), array([0., 0., 1., 0.]), array([0., 0., 0., 1.])]

# %%
# N = 1_000
num_iterations = N
learning_rate = np.sqrt(np.log(num_weights) / (100*num_iterations))
egpolicytree = EGPolicyTree(cover, learning_rate, depth=2)
# print(np.mean(eval_data[0][-1], axis=0))
egpolicytree.fit(eval_data, num_iterations, num_subsamples=2*N, use_true_rewards=True)

optimal_policy = egpolicytree.trained_policy


# best_egpolicytree = EGPolicyTree(cover, learning_rate)
# best_egpolicytree.fit(eval_data, num_iterations, use_true_rewards=True)

# mixture_regrets = []
# for expert_id in range(NUM_WEIGHTS):
#     mixture_weights = cover[expert_id]
#     mixture_regret = compute_mixture_regret(egpolicytree.trained_policy, best_egpolicytree.trained_policy, mixture_weights, eval_data)
#     mixture_regrets.append(mixture_regret)
# Out:
# Subsampling data...
# Computing source scores...
# Computing max policy values...
# 1
# [array([[2.04394543, 0.2589849 ],
#        [1.51171504, 2.86181234],
#        [4.57793034, 0.99332676],
#        ...,
#        [0.98722865, 3.2830424 ],
#        [3.0838231 , 1.44444119],
#        [2.52468212, 0.80157998]])]
# [[2.04394543 0.2589849 ]
#  [1.51171504 2.86181234]
#  [4.57793034 0.99332676]
#  ...
#  [0.98722865 3.2830424 ]
#  [3.0838231  1.44444119]
#  [2.52468212 0.80157998]]
# for expert 0...
# Training the model...
#   0%|                                                           | 0/500 [00:00<?, ?it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 0: Policy value: 2.0450151504609755
# INFO:src.egpolicytree:Iteration 0: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 0: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 0: Expert distribution after update: [1.]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 1: Policy value: 2.0326693694395215
# INFO:src.egpolicytree:Iteration 1: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 1: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 1: Expert distribution after update: [1.]
#   0%|▏                                                  | 2/500 [00:00<00:32, 15.14it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 2: Policy value: 2.0468024100399975
# INFO:src.egpolicytree:Iteration 2: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 2: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 2: Expert distribution after update: [1.]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 3: Policy value: 2.0191657037064146
# INFO:src.egpolicytree:Iteration 3: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 3: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 3: Expert distribution after update: [1.]
#   1%|▍                                                  | 4/500 [00:00<00:32, 15.21it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 4: Policy value: 2.051731394725639
# INFO:src.egpolicytree:Iteration 4: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 4: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 4: Expert distribution after update: [1.]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 5: Policy value: 2.036057106728654
# INFO:src.egpolicytree:Iteration 5: Gradients: [0.]
# INFO:src.egpolicytree:Iteration 5: Expert distribution before update: [1.]
# INFO:src.egpolicytree:Iteration 5: Expert distribution after update:
/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[352], line 6
#       4 egpolicytree = EGPolicyTree(cover, learning_rate, depth=2)
#       5 # print(np.mean(eval_data[0][-1], axis=0))
# ----> 6 egpolicytree.fit(eval_data, num_iterations, num_subsamples=2*N, use_true_rewards=True)
#       8 optimal_policy = egpolicytree.trained_policy
#      11 # best_egpolicytree = EGPolicyTree(cover, learning_rate)
#      12 # best_egpolicytree.fit(eval_data, num_iterations, use_true_rewards=True)
#      13
#    (...)
#      17 #     mixture_regret = compute_mixture_regret(egpolicytree.trained_policy, best_egpolicytree.trained_policy, mixture_weights, eval_data)
#      18 #     mixture_regrets.append(mixture_regret)
#
# File ~/Desktop/eg-opo/src/egpolicytree.py:93, in EGPolicyTree.fit(self, data, num_iterations, num_subsamples, use_true_rewards)
#      91 print("Training the model...")
#      92 for iteration in tqdm(range(num_iterations)):
# ---> 93     best_response_policy = self.__get_best_response_policy(source_scores)
#      95     # # Compute the expert policy value of optimal policy.
#      96     # expert_policy_value = 0.0
#      97     # for source_id in source_scores:
#    (...)
#     102     # self.logger.info(f"Policy evaluated. Value: {expert_policy_value / len(source_scores)}")
#     103     # print(np.mean(subsampled_data[0][-1], axis=0))
#     104     expert_policy_value = utils.compute_mixture_regret_random(
#     105         self.experts_distro, subsampled_data
#     106     )
#
# File ~/Desktop/eg-opo/src/egpolicytree.py:243, in EGPolicyTree.__get_best_response_policy(self, source_scores)
#     241 scores_r = numpy2ri.py2rpy(all_scores)
#     242 covariates_r = numpy2ri.py2rpy(all_covariates)
# --> 243 policy = policytree.policy_tree(covariates_r, scores_r, depth=self.depth)
#     244 self.logger.info(f"Best response policy created with depth {self.depth}")
#     245 return policy
#
# File /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File /opt/miniconda3/envs/eg-opo/lib/python3.12/site-packages/rpy2/rinterface.py:811, in SexpClosure.__call__(self, *args, **kwargs)
#     806 call_r = rmemory.protect(
#     807     _rinterface.build_rcall(self.__sexp__._cdata, args,
#     808                             kwargs.items()))
#     809 call_context = evaluation_context.get()
#     810 res = rmemory.protect(
# --> 811     openrlib.rlib.R_tryEval(
#     812         call_r,
#     813         call_context.__sexp__._cdata,
#     814         error_occured)
#     815 )
#     816 if error_occured[0]:
#     817     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#
# KeyboardInterrupt:

# %%
np.mean(eval_data[0][-1], axis=0)
# Out:
# array([-1.47182105, -1.08285132,  1.25070865,  1.59487191, 10.21654249])

# %%
def __subsample_data(data, sample_size):
        subsampled_data = {}
        for source_id, dataset in data.items():
            num_samples = dataset[0].shape[0]
            if num_samples < sample_size:
                raise ValueError(f"Sample size {sample_size} is larger than the dataset size for source_id {source_id}")
            
            indices = np.array(random.sample(range(num_samples), sample_size))
            # print(indices)
            subsampled_dataset = []
            for arr in dataset:
                arr_sub = np.array([arr[i] for i in indices])
                subsampled_dataset.append(arr_sub)
            subsampled_data[source_id] = subsampled_dataset

        return subsampled_data

res = __subsample_data(eval_data, 100)
np.mean(res[0][-1], axis=0)
# Out:
# array([-7.73569603,  3.61113461, 10.37142777, -4.37278644, 13.74569557])

# %%
print(egpolicytree.trained_policy)
# Out:
# policy_tree object
# Tree depth:  2
# Actions:  1 2 3 4 5
# Variable splits:
# (1) split_variable: X2  split_value: -0.210899
#   (2) split_variable: X3  split_value: 0.0165732
#     (4) * action: 4
#     (5) * action: 5
#   (3) split_variable: X3  split_value: -0.149975
#     (6) * action: 3
#     (7) * action: 4

# %% [markdown]
# ### Train Mixture Policies

# %%
from rpy2.robjects import r, numpy2ri
import rpy2.robjects.packages as rpackages
import rpy2.robjects.vectors as rvectors

# Activate the automatic conversion between R and numpy objects
numpy2ri.activate()

policytree = rpackages.importr('policytree')
grf = rpackages.importr('grf')

# %%
opt_source_policies = {}

for expert_id in range(len(cover)):
    mixture_weights = cover[expert_id]
    
    for source_id in range(NUM_SOURCES):
        # Train policy
        covariates, rewards, treatment, _ = eval_data[i]
        covariates_r = numpy2ri.py2rpy(covariates)          # ns x p
        rewards_r = rvectors.FloatVector(rewards)           # ns x 1
        treatment_r = rvectors.FactorVector(treatment)      # ns x 1
        
        multiforest = grf.multi_arm_causal_forest(covariates_r, rewards_r, treatment_r)
        scores = np.array(policytree.double_robust_scores(multiforest)) # ns x d
        scores_r = numpy2ri.py2rpy(scores)
        policy = policytree.policy_tree(covariates_r, scores_r, depth=2)
        policy_value = utils.evaluate_policy(policy, covariates, scores)
    
        # Get best policy
        covariates, _, _, true_rewards = eval_data[i]
        covariates_r = numpy2ri.py2rpy(covariates)          # ns x p
        true_rewards_r = numpy2ri.py2rpy(true_rewards)
        best_policy = policytree.policy_tree(covariates_r, true_rewards_r, depth=2)
        best_policy_value = utils.evaluate_policy(best_policy, covariates, true_rewards)
    
        opt_source_policies[source_id] = {'policy': policy, 'best_policy': best_policy}

# %%
print(opt_source_policies[0]["policy"])
# Out:
# policy_tree object
# Tree depth:  2
# Actions:  1 2 3 4 5
# Variable splits:
# (1) split_variable: X3  split_value: 0.0540058
#   (2) split_variable: X2  split_value: -0.299603
#     (4) * action: 4
#     (5) * action: 5
#   (3) split_variable: X4  split_value: -0.128817
#     (6) * action: 1
#     (7) * action: 3

# %% [markdown]
# # Local policies

# %%
def subsample_data(data, sample_size):
        num_samples = data[0].shape[0]
        if num_samples < sample_size:
            raise ValueError(f"Sample size {sample_size} is larger than the dataset size for source_id {source_id}")
        
        indices = np.array(random.sample(range(num_samples), sample_size))
        # print(indices)
        subsampled_dataset = []
        for arr in data:
            arr_sub = np.array([arr[i] for i in indices])
            subsampled_dataset.append(arr_sub)

        return subsampled_dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
# import rpy2.robjects as ro
# from rpy2.robjects import numpy2ri, rvectors
# import grf
# import policytree
# import utils
import pandas as pd  # For rolling average calculation

# # Ensure conversion between numpy and R types
# numpy2ri.activate()
NUM_SEEDS = 2

# Range of subsample sizes
subsample_sizes = np.arange(10, 501, 10)  # Adjust step size as needed
# NUM_SOURCES = 3  # Example value, update with the actual number of sources

# Initialize dictionaries to store policy, best policy, and regret values for each source
policy_values_dict = {source_id: [] for source_id in range(NUM_SOURCES)}
best_policy_values_dict = {source_id: [] for source_id in range(NUM_SOURCES)}
regret_values_dict = {source_id: np.zeros((NUM_SEEDS, len(subsample_sizes))) for source_id in range(2*NUM_SOURCES)}
mixture_regret_values_dict = {source_id: np.zeros((NUM_SEEDS, len(subsample_sizes))) for source_id in range(2*NUM_SOURCES)}

# # Default span is the largest x value
# span = 20

# Define a smoothing function using a rolling window average
def smooth_values(values, span):
    values_series = pd.Series(values)
    return values_series.rolling(window=span, min_periods=1, center=True).mean().tolist()

best_policy_values_dict = {}


for seed in range(NUM_SEEDS):
    # Loop through each source and subsample size
    for source_id in range(NUM_SOURCES):
    
        train_data_i = train_data[source_id]
        eval_covariates, eval_rewards, eval_treatment, eval_true_rewards = train_data[source_id]
        # test_covariates, test_rewards, test_treatment, test_true_rewards = test_data[source_id]
    
        # Convert data to R objects
        eval_covariates_r = numpy2ri.py2rpy(eval_covariates)          # ns x p
        eval_rewards_r = rvectors.FloatVector(eval_rewards)           # ns x 1
        eval_treatment_r = rvectors.FactorVector(eval_treatment)      # ns x 1
        eval_true_rewards_r = numpy2ri.py2rpy(eval_true_rewards)
        best_policy = policytree.policy_tree(eval_covariates_r, eval_true_rewards_r, depth=2)
    
        # Train multi-arm causal forest
        multiforest = grf.multi_arm_causal_forest(eval_covariates_r, eval_rewards_r, eval_treatment_r)
        
        # Calculate double robust scores
        eval_scores = np.array(policytree.double_robust_scores(multiforest)) # ns x d
    
        # Train and evaluate the best policy (using true rewards)
        # true_rewards_r = numpy2ri.py2rpy(true_rewards)
        best_policy_value = utils.evaluate_policy(best_policy, eval_covariates, eval_scores, best=True)
        # best_policy_values_dict[source_id].append(best_policy_value)  # Store the best policy value
        print(best_policy_value)
    
        # best_policy_values_dict[source_id] = best_policy_value
        
        for i, subsample_size in enumerate(subsample_sizes):
            # Subsample the data
            # covariates, rewards, treatment, true_rewards = subsample_data(train_data[0], subsample_size)
            covariates, rewards, treatment, true_rewards = subsample_data(train_data[source_id], subsample_size)
            
            # Convert data to R objects
            covariates_r = numpy2ri.py2rpy(covariates)          # ns x p
            rewards_r = rvectors.FloatVector(-rewards)          # ns x 1
            treatment_r = rvectors.FactorVector(treatment)      # ns x 1
            
            # Train multi-arm causal forest
            multiforest = grf.multi_arm_causal_forest(covariates_r, rewards_r, treatment_r)
            
            # Calculate double robust scores
            scores = np.array(policytree.double_robust_scores(multiforest)) # ns x d
            scores_r = numpy2ri.py2rpy(scores)
            
            # Train policy tree
            policy = policytree.policy_tree(covariates_r, scores_r, depth=2)
    
            # Evaluate policy
            policy_value = utils.evaluate_policy(policy, eval_covariates, eval_scores)
            policy_values_dict[source_id].append(policy_value)  # Store the policy value for this source and subsample size
            
            # Calculate regret (best policy value - policy value)
            regret_value = policy_value
            regret_values_dict[source_id][seed, i] = best_policy_value - regret_value  # Store the regret value

            mixture_regret_values_dict[source_id][seed, i] = utils.compute_mixture_regret(
                policy, policy, [.05, .05, .9], train_data
            )
    
            regret_values_dict[source_id+NUM_SOURCES][seed, i] = best_policy_value - utils.evaluate_random_policy(eval_covariates, eval_scores)

local_regret_values_dict = regret_values_dict
# Out:
# 3.096666500298674
# 3.9454596991139996
# 4.586263927928836
# 3.1031019392144903
# 3.96459795102172
# 4.575578971024643

# %%
# Calculate mean and standard deviation across seeds for each source
mean_regret = {source_id: np.mean(local_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}
std_regret = {source_id: np.std(local_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}

# Span for the rolling window smoothing
span = 10

# Apply smoothing to both the mean and standard deviation using the rolling average function
smooth_mean_regret = {source_id: smooth_values(mean_regret[source_id], span) for source_id in range(NUM_SOURCES)}
smooth_std_regret = {source_id: smooth_values(std_regret[source_id], span) for source_id in range(NUM_SOURCES)}

# Plot the results with smoothed mean and spread across seeds
plt.figure(figsize=(12, 8))

for source_id in range(NUM_SOURCES):
    # Plot smoothed mean regret with shaded smoothed standard deviation
    plt.plot(subsample_sizes, smooth_mean_regret[source_id], label=f'Source {source_id} Mean Regret', linestyle='-')
    plt.fill_between(subsample_sizes, 
                     np.array(smooth_mean_regret[source_id]) - np.array(smooth_std_regret[source_id]),
                     np.array(smooth_mean_regret[source_id]) + np.array(smooth_std_regret[source_id]), 
                     alpha=0.05)

# Add legend and labels
plt.xlabel('Subsample Size')
plt.ylabel('Regret')
plt.title('Smoothed Mean Regret with Spread Across Seeds')
plt.legend(loc='upper right')  # Position the legend in the upper right corner (adjust as needed)
plt.grid(True)
plt.show()

# %%
# Calculate mean and standard deviation across seeds for each source
mean_regret = {source_id: np.mean(mixture_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}
std_regret = {source_id: np.std(mixture_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}

# Span for the rolling window smoothing
span = 10

# Apply smoothing to both the mean and standard deviation using the rolling average function
smooth_mean_regret = {source_id: smooth_values(mean_regret[source_id], span) for source_id in range(NUM_SOURCES)}
smooth_std_regret = {source_id: smooth_values(std_regret[source_id], span) for source_id in range(NUM_SOURCES)}

# Plot the results with smoothed mean and spread across seeds
plt.figure(figsize=(12, 8))

for source_id in range(NUM_SOURCES):
    # Plot smoothed mean regret with shaded smoothed standard deviation
    plt.plot(subsample_sizes, smooth_mean_regret[source_id], label=f'Source {source_id} Mean Regret', linestyle='-')
    plt.fill_between(subsample_sizes, 
                     np.array(smooth_mean_regret[source_id]) - np.array(smooth_std_regret[source_id]),
                     np.array(smooth_mean_regret[source_id]) + np.array(smooth_std_regret[source_id]), 
                     alpha=0.05)

# Add legend and labels
plt.xlabel('Subsample Size')
plt.ylabel('Regret')
plt.title('Smoothed Mean Regret with Spread Across Seeds')
plt.legend(loc='upper right')  # Position the legend in the upper right corner (adjust as needed)
plt.grid(True)
plt.show()

# %% [markdown]
# # Global policy

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import rpy2.robjects as ro
# from rpy2.robjects import numpy2ri, rvectors
# import grf
# import policytree
# import utils
# import pandas as pd  # For rolling average calculation

# # Ensure conversion between numpy and R types
# numpy2ri.activate()

# Range of subsample sizes
subsample_sizes = np.arange(10, 501, 10)  # Adjust step size as needed
# NUM_SOURCES = 3  # Example value, update with the actual number of sources

# Initialize lists to store policy, best policy, and regret values (combined data)
policy_values_combined = []
best_policy_values_combined = []
regret_values_combined = []

combined_regret_values_dict = {source_id: np.zeros((NUM_SEEDS, len(subsample_sizes))) for source_id in range(NUM_SOURCES)}
combined_mixture_regret_values = np.zeros((NUM_SEEDS, len(subsample_sizes)))


# Default span is the largest x value
# span = subsample_sizes[-1]

# Define a smoothing function using a rolling window average
# def smooth_values(values, span):
#     values_series = pd.Series(values)
#     return values_series.rolling(window=span, min_periods=1, center=True).mean().tolist()

# Combine data from all sources
all_covariates = np.vstack([train_data[i][0] for i in range(NUM_SOURCES)])  # Combine covariates
all_rewards = np.hstack([train_data[i][1] for i in range(NUM_SOURCES)])     # Combine rewards
all_treatment = np.hstack([train_data[i][2] for i in range(NUM_SOURCES)])   # Combine treatment
all_true_rewards = np.vstack([train_data[i][3] for i in range(NUM_SOURCES)])# Combine true rewards

print(all_covariates.shape)
print(all_rewards.shape)
print(all_treatment.shape)
print(all_true_rewards.shape)

# Convert combined data to R objects
covariates_r = numpy2ri.py2rpy(all_covariates)        # ns x p
rewards_r = rvectors.FloatVector(all_rewards)         # ns x 1
treatment_r = rvectors.FactorVector(all_treatment)    # ns x 1
true_rewards_r = numpy2ri.py2rpy(all_true_rewards)

# Train multi-arm causal forest on the combined data
multiforest = grf.multi_arm_causal_forest(covariates_r, rewards_r, treatment_r)

# Calculate double robust scores for the combined data
scores = np.array(policytree.double_robust_scores(multiforest))  # ns x d
scores_r = numpy2ri.py2rpy(scores)

# Train the best policy on the combined data using true rewards
best_policy = policytree.policy_tree(covariates_r, scores_r, depth=2)
best_policy_value = utils.evaluate_policy(best_policy, all_covariates, scores, best=True)

for seed in range(NUM_SEEDS):
    # Loop through each subsample size and evaluate policies
    for i, subsample_size in enumerate(subsample_sizes):
        # Subsample the combined data
        subsampled_covariates, subsampled_rewards, subsampled_treatment, subsampled_true_rewards = subsample_data(
            (all_covariates, all_rewards, all_treatment, all_true_rewards), max(10,int(subsample_size/NUM_SOURCES))
        )
        
        
        # Convert subsampled data to R objects
        subsampled_covariates_r = numpy2ri.py2rpy(subsampled_covariates)  # ns x p
        subsampled_rewards_r = rvectors.FloatVector(-subsampled_rewards)   # ns x 1
        subsampled_treatment_r = rvectors.FactorVector(subsampled_treatment)  # ns x 1
    
        # Train multi-arm causal forest on the combined data
        multiforest = grf.multi_arm_causal_forest(subsampled_covariates_r, subsampled_rewards_r, subsampled_treatment_r)
        
        # Calculate double robust scores for the combined data
        subsampled_scores = np.array(policytree.double_robust_scores(multiforest))  # ns x d
        subsampled_scores_r = numpy2ri.py2rpy(subsampled_scores)
            
        # Train policy tree on the subsampled data
        policy = policytree.policy_tree(subsampled_covariates_r, subsampled_scores_r, depth=2)
        
        # # Evaluate policy
        # policy_value = utils.evaluate_policy(policy, all_covariates, scores)
        # policy_values_combined.append(policy_value)  # Store the policy value
        
        # # Calculate regret (best policy value - policy value)
        # regret_value = best_policy_value - policy_value
        # regret_values_combined.append(regret_value)  # Store the regret value
    
        for source_id in range(NUM_SOURCES):
            eval_covariates, eval_rewards, eval_treatment, eval_true_rewards = train_data[source_id]
    
            # Convert data to R objects
            eval_covariates_r = numpy2ri.py2rpy(eval_covariates)          # ns x p
            eval_rewards_r = rvectors.FloatVector(eval_rewards)           # ns x 1
            eval_treatment_r = rvectors.FactorVector(eval_treatment)      # ns x 1
            eval_true_rewards_r = numpy2ri.py2rpy(eval_true_rewards)
            best_policy = policytree.policy_tree(eval_covariates_r, eval_true_rewards_r, depth=2)
        
            # Train multi-arm causal forest
            multiforest = grf.multi_arm_causal_forest(eval_covariates_r, eval_rewards_r, eval_treatment_r)
            
            # Calculate double robust scores
            eval_scores = np.array(policytree.double_robust_scores(multiforest)) # ns x d
        
            # Train and evaluate the best policy (using true rewards)
            # true_rewards_r = numpy2ri.py2rpy(true_rewards)
            best_policy_value = utils.evaluate_policy(best_policy, eval_covariates, eval_scores, best=True)
            # best_policy_values_dict[source_id].append(best_policy_value)  # Store the best policy value
            # print(best_policy_value)
            
            # Evaluate policy
            policy_value = utils.evaluate_policy(policy, eval_covariates, eval_scores)
            policy_values_dict[source_id].append(policy_value)  # Store the policy value for this source and subsample size
            
            # Calculate regret (best policy value - policy value)
            regret_value = policy_value
            combined_regret_values_dict[source_id][seed, i] = best_policy_value - regret_value  # Store the regret value

        combined_mixture_regret_values[seed, i] = utils.compute_mixture_regret(
                policy, policy, [.05, .05, .9], train_data
            )
# Out:
# (1500, 4)
# (1500,)
# (1500,)
# (1500, 2)

# %%
span = 10

mean_regret = {source_id: np.mean(combined_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}
std_regret = {source_id: np.std(combined_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}

smooth_mean_regret = {source_id: smooth_values(mean_regret[source_id], span) for source_id in range(NUM_SOURCES)}
smooth_std_regret = {source_id: smooth_values(std_regret[source_id], span) for source_id in range(NUM_SOURCES)}

plt.figure(figsize=(12, 8))

for source_id in range(NUM_SOURCES):
    plt.plot(subsample_sizes, smooth_mean_regret[source_id], label=f'Source {source_id} Mean Regret', linestyle='-')
    plt.fill_between(subsample_sizes, 
                     np.array(smooth_mean_regret[source_id]) - np.array(smooth_std_regret[source_id]),
                     np.array(smooth_mean_regret[source_id]) + np.array(smooth_std_regret[source_id]), 
                     alpha=0.05)

plt.xlabel('Subsample Size')
plt.ylabel('Regret')
plt.title('Smoothed Mean Regret and Spread across Seeds')
plt.legend()
plt.grid(True)
plt.show()

# %%
span = 20

mean_regret = np.mean(combined_mixture_regret_values, axis=0)
std_regret = np.std(combined_mixture_regret_values, axis=0)

smooth_mean_regret = smooth_values(mean_regret, span)
smooth_std_regret = smooth_values(std_regret, span)

plt.figure(figsize=(12, 8))

plt.plot(subsample_sizes, smooth_mean_regret, label=f'Mean Regret', linestyle='-')
plt.fill_between(subsample_sizes, 
                 np.array(smooth_mean_regret) - np.array(smooth_std_regret),
                 np.array(smooth_mean_regret) + np.array(smooth_std_regret), 
                 alpha=0.05)

plt.xlabel('Subsample Size')
plt.ylabel('Regret')
plt.title('Smoothed Mean Regret and Spread across Seeds')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # EG Policy Tree

# %%
subsample_sizes = np.arange(10, 501, 10)
cover = []
num_weights = NUM_SOURCES
for i in range(num_weights):
    distribution = np.zeros(num_weights)
    distribution[i] = 1
    cover.append(distribution)
print(cover)

def run_experiments(
    num_subsamples_list, 
    cover, 
    train_data, 
    test_data, 
):
    results = []
    num_weights = len(cover)

    mixture_results = []

    for num_subsamples in num_subsamples_list:
        expert_mixture_regrets = [[] for _ in range(2*num_weights)]
        mixture_regrets = []
        num_iterations = max(10, num_subsamples)
        learning_rate = np.sqrt(np.log(num_weights) / (num_iterations * 10))

        num_repetitions = 2
        for _ in range(num_repetitions):
            # Initialize and train the policy
            egpolicytree = EGPolicyTree(cover, learning_rate, depth=2)
            egpolicytree.fit(train_data,
                             num_iterations=int(np.pow(num_iterations, 1/2)),
                             num_subsamples=max(10,int(num_subsamples/NUM_SOURCES))
                            )

            print(egpolicytree.trained_policy)

            # Compute mixture regrets for each expert
            for expert_id in range(NUM_SOURCES):
                mixture_weights = cover[expert_id]

                eval_covariates, eval_rewards, eval_treatment, eval_true_rewards = train_data[expert_id]
                # test_covariates, test_rewards, test_treatment, test_true_rewards = test_data[source_id]
            
                # Convert data to R objects
                eval_covariates_r = numpy2ri.py2rpy(eval_covariates)          # ns x p
                eval_rewards_r = rvectors.FloatVector(eval_rewards)           # ns x 1
                eval_treatment_r = rvectors.FactorVector(eval_treatment)      # ns x 1
                eval_true_rewards_r = numpy2ri.py2rpy(eval_true_rewards)
                best_policy = policytree.policy_tree(eval_covariates_r, eval_true_rewards_r, depth=2)
            
                # Train multi-arm causal forest
                multiforest = grf.multi_arm_causal_forest(eval_covariates_r, eval_rewards_r, eval_treatment_r)
                
                # Calculate double robust scores
                eval_scores = np.array(policytree.double_robust_scores(multiforest)) # ns x d
                
                # mixture_regret = utils.compute_mixture_regret(
                #     egpolicytree.trained_policy, 
                #     optimal_policy,
                #     mixture_weights,
                #     train_data
                # )
                mixture_regret = utils.compute_regret(
                    egpolicytree.trained_policy, 
                    egpolicytree.trained_policy,
                    eval_covariates,
                    eval_scores
                )
                expert_mixture_regrets[expert_id].append(mixture_regret)

                # random_regret = utils.compute_mixture_regret_random(mixture_weights, train_data)
                
                random_regret = best_policy_value - utils.evaluate_random_policy(eval_covariates, eval_scores)
                expert_mixture_regrets[expert_id+NUM_SOURCES].append(random_regret)

            mixture_regrets.append(
                utils.compute_mixture_regret(
                    egpolicytree.trained_policy, egpolicytree.trained_policy, [.05, .05, .9], train_data
                )
            )

        for expert_id in range(2*num_weights):
            mean_regret = np.mean(expert_mixture_regrets[expert_id])
            std_regret = np.std(expert_mixture_regrets[expert_id])
            results.append((num_subsamples, expert_id, mean_regret, std_regret))

        mixture_mean_regret = np.mean(mixture_regrets)
        mixture_std_regret = np.std(mixture_regrets)
        mixture_results.append((num_subsamples, mixture_mean_regret, mixture_std_regret))
    
    return results, mixture_results
# Out:
# [array([1., 0., 0.]), array([0., 1., 0.]), array([0., 0., 1.])]

# %%
# Define parameters
# num_subsamples_list = [x for x in range(20, 201, 1)]  # Example subsample sizes

# num_repetitions = 1
# cover = np.random.rand(10, 10)  # Replace with actual cover
# learning_rate = 0.1
# learning_rate = np.sqrt(np.log(num_weights) / (num_subsamples * 10))
# data = np.random.rand(100, 10)  # Replace with actual data
# eval_data = np.random.rand(20, 10)  # Replace with actual eval data
# num_iterations = None
# num_weights = 10

# Run experiments
results, mixture_results = run_experiments(
    subsample_sizes, 
    cover, 
    train_data, 
    test_data, 
)
# Out:
# Subsampling data...
# Computing source scores...
# Computing max policy values...
# for expert 0...
# for expert 1...
# for expert 2...
# Training the model...
#   0%|                                                                         | 0/3 [00:00<?, ?it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 0: Policy value: 7.5213288780689105
# INFO:src.egpolicytree:Iteration 0: Gradients: [-2.03719092 -2.06733742 -3.8996318 ]
# INFO:src.egpolicytree:Iteration 0: Expert distribution before update: [0.33333333 0.33333333 0.33333333]
# INFO:src.egpolicytree:Iteration 0: Expert distribution after update: [0.35465071 0.35353291 0.29181638]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 1: Policy value: 5.096186770101466
# INFO:src.egpolicytree:Iteration 1: Gradients: [-2.03719092 -2.06733742 -3.8996318 ]
# INFO:src.egpolicytree:Iteration 1: Expert distribution before update: [0.35465071 0.35353291 0.29181638]
# INFO:src.egpolicytree:Iteration 1: Expert distribution after update: [0.37267539 0.37043716 0.25688745]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 2: Policy value: 4.869031927269077
# INFO:src.egpolicytree:Iteration 2: Gradients: [-2.03719092 -2.06733742 -3.8996318 ]
# INFO:src.egpolicytree:Iteration 2: Expert distribution before update: [0.37267539 0.37043716 0.25688745]
# INFO:src.egpolicytree:Iteration 2: Expert distribution after update: [0.38796355 0.38462227 0.22741418]
# 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 303.95it/s]
# policy_tree object
# Tree depth:  2
# Actions:  1 2
# Variable splits:
# (1) split_variable: X3  split_value: -0.162723
#   (2) split_variable: X3  split_value: -0.442679
#     (4) * action: 1
#     (5) * action: 2
#   (3) split_variable: X2  split_value: -0.424573
#     (6) * action: 2
#     (7) * action: 1
# Subsampling data...
# Computing source scores...
# Computing max policy values...
# for expert 0...
# for expert 1...
# for expert 2...
# Training the model...
#   0%|                                                                         | 0/3 [00:00<?, ?it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 0: Policy value: 6.11353643173552
# INFO:src.egpolicytree:Iteration 0: Gradients: [-7.26223597 -1.30527903 -5.04302389]
# INFO:src.egpolicytree:Iteration 0: Expert distribution before update: [0.33333333 0.33333333 0.33333333]
# INFO:src.egpolicytree:Iteration 0: Expert distribution after update: [0.24228252 0.45207227 0.30564521]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 1: Policy value: 8.659782409224112
# INFO:src.egpolicytree:Iteration 1: Gradients: [-7.26223597 -1.30527903 -5.04302389]
# INFO:src.egpolicytree:Iteration 1: Expert distribution before update: [0.24228252 0.45207227 0.30564521]
# INFO:src.egpolicytree:Iteration 1: Expert distribution after update: [0.17109908 0.56241406 0.26648686]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 2: Policy value: 5.635594045545009
# INFO:src.egpolicytree:Iteration 2: Gradients: [-7.26223597 -1.30527903 -5.04302389]
# INFO:src.egpolicytree:Iteration 2: Expert distribution before update: [0.17109908 0.56241406 0.26648686]
# INFO:src.egpolicytree:Iteration 2: Expert distribution after update: [0.11896079 0.65642293 0.22461628]
# 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 333.34it/s]
# policy_tree object
# Tree depth:  2
# Actions:  1 2
# Variable splits:
# (1) split_variable: X2  split_value: -0.0804619
#   (2) split_variable: X1  split_value: -0.223877
#     (4) * action: 1
#     (5) * action: 2
#   (3) split_variable: X1  split_value: -0.71421
#     (6) * action: 2
#     (7) * action: 1
# Subsampling data...
# Computing source scores...
# Computing max policy values...
# for expert 0...
# for expert 1...
# for expert 2...
# Training the model...
#   0%|                                                                         | 0/4 [00:00<?, ?it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 0: Policy value: 10.150533780150361
# INFO:src.egpolicytree:Iteration 0: Gradients: [-4.3598854  -5.15986862  0.        ]
# INFO:src.egpolicytree:Iteration 0: Expert distribution before update: [0.33333333 0.33333333 0.33333333]
# INFO:src.egpolicytree:Iteration 0: Expert distribution after update: [0.30088546 0.28358345 0.41553109]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 1: Policy value: 8.055766301429209
# INFO:src.egpolicytree:Iteration 1: Gradients: [-4.3598854  -5.15986862  0.        ]
# INFO:src.egpolicytree:Iteration 1: Expert distribution before update: [0.30088546 0.28358345 0.41553109]
# INFO:src.egpolicytree:Iteration 1: Expert distribution after update: [0.26704401 0.2385166  0.49443939]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 2: Policy value: 9.503688525183271
# INFO:src.egpolicytree:Iteration 2: Gradients: [-4.3598854  -5.15986862  0.        ]
# INFO:src.egpolicytree:Iteration 2: Expert distribution before update: [0.26704401 0.2385166  0.49443939]
# INFO:src.egpolicytree:Iteration 2: Expert distribution after update: [0.23408314 0.19904755 0.56686931]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 3: Policy value: 5.6764840131745125
# INFO:src.egpolicytree:Iteration 3: Gradients: [-4.3598854  -5.15986862  0.        ]
# INFO:src.egpolicytree:Iteration 3: Expert distribution before update: [0.23408314 0.19904755 0.56686931]
# INFO:src.egpolicytree:Iteration 3: Expert distribution after update: [0
/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 11: Policy value: 6.846354148247646
# INFO:src.egpolicytree:Iteration 11: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 11: Expert distribution before update: [0.31512958 0.31527427 0.36959615]
# INFO:src.egpolicytree:Iteration 11: Expert distribution after update: [0.31398687 0.31413987 0.37187326]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 12: Policy value: 7.862692214569236
# INFO:src.egpolicytree:Iteration 12: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 12: Expert distribution before update: [0.31398687 0.31413987 0.37187326]
# INFO:src.egpolicytree:Iteration 12: Expert distribution after update: [0.3128954  0.31305625 0.37404835]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 13: Policy value: 7.646840165514769
# INFO:src.egpolicytree:Iteration 13: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 13: Expert distribution before update: [0.3128954  0.31305625 0.37404835]
# INFO:src.egpolicytree:Iteration 13: Expert distribution after update: [0.31185092 0.31201921 0.37612987]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 14: Policy value: 6.4732582180515585
# INFO:src.egpolicytree:Iteration 14: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 14: Expert distribution before update: [0.31185092 0.31201921 0.37612987]
# INFO:src.egpolicytree:Iteration 14: Expert distribution after update: [0.31084968 0.31102505 0.37812527]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 15: Policy value: 7.241691327379931
# INFO:src.egpolicytree:Iteration 15: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 15: Expert distribution before update: [0.31084968 0.31102505 0.37812527]
# INFO:src.egpolicytree:Iteration 15: Expert distribution after update: [0.3098884  0.31007048 0.38004112]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 16: Policy value: 6.721089230690284
# INFO:src.egpolicytree:Iteration 16: Gradients: [-1.09083576 -1.08769355  0.        ]
# INFO:src.egpolicytree:Iteration 16: Expert distribution before update: [0.3098884  0.31007048 0.38004112]
# INFO:src.egpolicytree:Iteration 16: Expert distribution after update: [0.30896413 0.30915261 0.38188325]
# 100%|██████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 109.33it/s]
# policy_tree object
# Tree depth:  2
# Actions:  1 2
# Variable splits:
# (1) split_variable: X2  split_value: -0.81638
#   (2) split_variable: X2  split_value: -0.927088
#     (4) * action: 2
#     (5) * action: 1
#   (3) split_variable: X1  split_value: -0.0428631
#     (6) * action: 2
#     (7) * action: 1
#
# Subsampling data...
# Computing source scores...
# Computing max policy values...
# for expert 0...
# for expert 1...
# for expert 2...
# Training the model...
#   0%|                                                                        | 0/17 [00:00<?, ?it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 0: Policy value: 7.3673743274291725
# INFO:src.egpolicytree:Iteration 0: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 0: Expert distribution before update: [0.33333333 0.33333333 0.33333333]
# INFO:src.egpolicytree:Iteration 0: Expert distribution after update: [0.33396695 0.33675418 0.32927887]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 1: Policy value: 6.017832076260324
# INFO:src.egpolicytree:Iteration 1: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 1: Expert distribution before update: [0.33396695 0.33675418 0.32927887]
# INFO:src.egpolicytree:Iteration 1: Expert distribution after update: [0.33451852 0.33986582 0.32561566]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 2: Policy value: 6.179572993051698
# INFO:src.egpolicytree:Iteration 2: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 2: Expert distribution before update: [0.33451852 0.33986582 0.32561566]
# INFO:src.egpolicytree:Iteration 2: Expert distribution after update: [0.33500358 0.34271881 0.32227761]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 3: Policy value: 6.810130055723537
# INFO:src.egpolicytree:Iteration 3: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 3: Expert distribution before update: [0.33500358 0.34271881 0.32227761]
# INFO:src.egpolicytree:Iteration 3: Expert distribution after update: [0.33543381 0.3453522  0.319214  ]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 4: Policy value: 6.1338786503233536
# INFO:src.egpolicytree:Iteration 4: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 4: Expert distribution before update: [0.33543381 0.3453522  0.319214  ]
# INFO:src.egpolicytree:Iteration 4: Expert distribution after update: [0.33581819 0.34779676 0.31638505]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 5: Policy value: 6.723937423223631
# INFO:src.egpolicytree:Iteration 5: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 5: Expert distribution before update: [0.33581819 0.34779676 0.31638505]
# INFO:src.egpolicytree:Iteration 5: Expert distribution after update: [0.33616378 0.3500772  0.31375903]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 6: Policy value: 6.061700688360065
# INFO:src.egpolicytree:Iteration 6: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 6: Expert distribution before update: [0.33616378 0.3500772  0.31375903]
# INFO:src.egpolicytree:Iteration 6: Expert distribution after update: [0.33647618 0.35221364 0.31131018]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 7: Policy value: 6.5293021593088145
# INFO:src.egpolicytree:Iteration 7: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 7: Expert distribution before update: [0.33647618 0.35221364 0.31131018]
# INFO:src.egpolicytree:Iteration 7: Expert distribution after update: [0.33675993 0.35422271 0.30901735]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 8: Policy value: 6.4968902008599265
# INFO:src.egpolicytree:Iteration 8: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 8: Expert distribution before update: [0.33675993 0.35422271 0.30901735]
# INFO:src.egpolicytree:Iteration 8: Expert distribution after update: [0.33701876 0.35611829 0.30686294]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 9: Policy value: 6.46553976744905
# INFO:src.egpolicytree:Iteration 9: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 9: Expert distribution before update: [0.33701876 0.35611829 0.30686294]
# INFO:src.egpolicytree:Iteration 9: Expert distribution after update: [0.33725574 0.3579121  0.30483216]
# INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 10: Policy value: 6.283528421843246
# INFO:src.egpolicytree:Iteration 10: Gradients: [-0.61077282 -0.1760289  -1.35026417]
# INFO:src.egpolicytree:Iteration 10: Expert distribution before update: [0.33725574 0.3579121  0.30483216]
# INFO:src.egpolicytree:Iteration 10: Expert distribution after update: [0.33747343 0.35961412 0.30291245]
#  65%|████████████████████████████████████████                      | 11/17 [00:00<00:00, 104.42it/s]INFO:src.egpolicytree:Best response policy created with depth 2
# INFO:src.egpolicytree:Iteration 11: Policy value: 6.608565568603289

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess

# # Apply smoothing to the results
# plot_policy_values_dict = {}
# plot_best_policy_values_dict = {}
# plot_regret_values_dict = {}

# span = 50
# for source_id in range(2*NUM_SOURCES):
#     # plot_policy_values_dict[source_id] = smooth_values(policy_values_dict[source_id], span)
#     # plot_best_policy_values_dict[source_id] = smooth_values(best_policy_values_dict[source_id], span)
#     plot_regret_values_dict[source_id] = smooth_values(regret_values_dict[source_id], span)

# # Plot the results for each source_id
# plt.figure(figsize=(12, 8))

# for source_id in range(2*NUM_SOURCES):
#     # plt.plot(subsample_sizes, policy_values_dict[source_id], label=f'Source {source_id} Policy Value (Smoothed)', marker='o')
#     # plt.plot(subsample_sizes, best_policy_values_dict[source_id], label=f'Source {source_id} Best Policy Value (Smoothed)', marker='x')
#     plt.plot(subsample_sizes, plot_regret_values_dict[source_id], label=f'Source {source_id} Regret (Smoothed)', linestyle='-')

# plt.xlabel('Subsample Size')
# plt.ylabel('Value')
# plt.title('Smoothed Policy, Best Policy, and Regret over Different Subsample Sizes per Source')
# plt.legend()
# plt.grid(True)
# plt.show()


# Convert results to a DataFrame for easy plotting
results_df = pd.DataFrame(results, columns=['num_subsamples', 'expert_id', 'mean_regret', 'std_regret'])
mixture_results_df = pd.DataFrame(mixture_results, columns=['num_subsamples', 'mean_regret', 'std_regret'])

span = 10
# Plot the results with smoothing
plt.figure(figsize=(12, 8))
for expert_id in range(num_weights):
    # if expert_id not in [1, 4]: continue
    expert_data = results_df[results_df['expert_id'] == expert_id]
    # expert_data = mixture_results_df

    # Lowess smoothing
    res = smooth_values(expert_data['mean_regret'], span)
    # smoothed_x = lowess_smoothed[:, 0]
    # smoothed_y = lowess_smoothed[:, 1]

    # Plot the smoothed line
    plt.plot(subsample_sizes, res, label=f'Expert {expert_id}')

    # # Calculate and plot the standard deviation bands
    lowess_smoothed_std_upper = smooth_values(expert_data['mean_regret'] + expert_data['std_regret'], span)
    lowess_smoothed_std_lower = smooth_values(expert_data['mean_regret'] - expert_data['std_regret'], span)
    
    plt.fill_between(subsample_sizes, lowess_smoothed_std_lower, lowess_smoothed_std_upper, alpha=0.05)


plt.figure(figsize=(12, 8))
expert_data = mixture_results_df
# Lowess smoothing
res = smooth_values(expert_data['mean_regret'], span)
# smoothed_x = lowess_smoothed[:, 0]
# smoothed_y = lowess_smoothed[:, 1]

# Plot the smoothed line
plt.plot(subsample_sizes, res, label=f'Expert {expert_id}')

# # Calculate and plot the standard deviation bands
lowess_smoothed_std_upper = smooth_values(expert_data['mean_regret'] + expert_data['std_regret'], span)
lowess_smoothed_std_lower = smooth_values(expert_data['mean_regret'] - expert_data['std_regret'], span)

plt.fill_between(subsample_sizes, lowess_smoothed_std_lower, lowess_smoothed_std_upper, alpha=0.05)

# for source_id in range(NUM_SOURCES):
#     # plot_policy_values_dict[source_id] = smooth_values(policy_values_dict[source_id], span)
#     # plot_best_policy_values_dict[source_id] = smooth_values(best_policy_values_dict[source_id], span)
#     plot_regret_values_dict[source_id] = smooth_values(regret_values_dict[source_id], span)

#     plt.plot(subsample_sizes, plot_regret_values_dict[source_id], label=f'Source {source_id} Regret (Smoothed)', linestyle='--')

mean_regret = {source_id: np.mean(local_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}
std_regret = {source_id: np.std(local_regret_values_dict[source_id], axis=0) for source_id in range(NUM_SOURCES)}

smooth_mean_regret = {source_id: smooth_values(mean_regret[source_id], span) for source_id in range(NUM_SOURCES)}
smooth_std_regret = {source_id: smooth_values(std_regret[source_id], span) for source_id in range(NUM_SOURCES)}

# plt.figure(figsize=(12, 8))

# for source_id in range(NUM_SOURCES):
#     plt.plot(subsample_sizes, smooth_mean_regret[source_id], label=f'Source {source_id} Mean Regret', linestyle='--')
#     plt.fill_between(subsample_sizes, 
#                      np.array(smooth_mean_regret[source_id]) - np.array(smooth_std_regret[source_id]),
#                      np.array(smooth_mean_regret[source_id]) + np.array(smooth_std_regret[source_id]), 
#                      alpha=0.05)

plt.xlabel('Number of Subsamples')
plt.ylabel('Mixture Regret')
plt.title('Mixture Regret vs Number of Subsamples for Each Expert')
plt.legend()
plt.show()
